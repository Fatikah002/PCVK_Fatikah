# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatikah002/PCVK_Fatikah/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
from google.colab import drive

# Acessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import random
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img)

# %%
#2
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
#3
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) # ubah ukuran (10, 10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
#4
black_img = np.zeros((512, 512, 3), dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik pt1 dan pt2
cv.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0, 255, 0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line (black_img, pt1=(0, 0), pt2=(512, 512), color=(255, 255, 255), thickness=5)
cv.circle(black_img, center=(400, 400), radius=50, color=(255, 0, 0), thickness=-1)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200], [400,300], [200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # PERTANYAAN PRAKTIKUM D3
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
# Jawab:
# *   Matplotlib: Format RGB, banyak opsi kustomisasi, cocok untuk analisis
# Tanpa matplotlib: OpenCV menampilkan
# *   format BGR, lebih sederhana, cocok untuk real-time
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data
# int16 dan int32?
#
# Jawab:
# *   int16: Range -32,768 hingga 32,767, ukuran memori lebih kecil
# *   int32: Range jauh lebih besar, konsumsi memori 2x lipat
#
#
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan
# kode berikut
#
# Jawab:
# *   Fungsi khusus Google Colab untuk menampilkan citra OpenCV di notebook
# *   Mengatasi keterbatasan cv2.imshow() yang tidak berfungsi di browser
#
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# Jawab:
#
# *   Modul io dari scikit-image (skimage) digunakan untuk operasi input/output gambar
# *   Membaca gambar dalam format RGB (berbeda dengan OpenCV yang BGR)
# *   Menyediakan fungsi imread(), imshow(), imsave() dengan interface yang konsisten

# %% [markdown]
# # TUGAS PRAKTIKUM D3
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya
# juga berubah?
#
# Jawab :
# Tidak, figsize hanya memengaruhi ukuran tampilan, bukan ukuran pixel citra.

# %%
# 2.Tampilkan image dalam channel Red-Blue dan Green-Blue saja!
rb = img3.copy()
rb[:,:,1] = 0   # tanpa Green

gb = img3.copy()
gb[:,:,0] = 0   # tanpa Red

plt.subplot(1,2,1)
plt.imshow(rb); plt.title("Red-Blue")
plt.axis("off")
plt.subplot(1,2,2)
plt.imshow(gb); plt.title("Green-Blue")
plt.axis("off")
plt.show()

# %%
img = img3[20:116, 25:121]
plt.figure()
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
#3. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
red_channel = img3[5:31,:,0]
plt.imshow(red_channel, cmap='Reds')
plt.axis("off")
plt.show()

# %%
img = img3.copy()
for i in range(5):
    x1, y1 = random.randint(0, 200), random.randint(0, 200)
    x2, y2 = x1 + random.randint(20, 100), y1 + random.randint(20, 100)
    color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    cv.rectangle(img, (x1, y1), (x2, y2), color, -1)

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(279.5), np.float64(179.5), np.float64(-0.5))

# %%
# 6.Tampilkan image dengan posisi terbalik!
img = cv.flip(img3,0)
plt.imshow(flip)

# %%
# 7.Buat rectangle dan circle pada bagian wajah dari image foto s anda saat beraktifitas (bukan pasfoto).
foto = cv.imread('kita.jpg')
foto_rgb = cv.cvtColor(foto, cv.COLOR_BGR2RGB)
out = foto_rgb.copy()
cv.rectangle(out, (450,850), (300,650), (255,0,0), 2)
cv.circle(out, (375,750), 70, (0,255,0), 2)

plt.imshow(out)
plt.show()

# %%
#8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space
#RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
b,g,r = cv.split(foto)
h,w = b.shape
cv.rectangle(b, (0,h-200), (200,h), 255, -1)

plt.imshow(b, cmap='Blues')
plt.axis("off")
plt.show()

# %%
#9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font,
# ukuran font, dan warna font yang sesuai keinginan anda.
img_text = foto_rgb.copy()
cv.putText(img_text, "Week2", (50,150),
            cv.FONT_HERSHEY_SCRIPT_COMPLEX, 5, (255,0,0), 3)

plt.imshow(img_text)
plt.axis("off")
plt.show()

# %% [markdown]
# 10. Tunjukkan code program anda pada bapak/ibu dosen
